# %% [markdown]
# ### API request to edmam to get nutrition analysis of Nepalese Lentil Curry
# API Documentation: https://developer.edamam.com/edamam-docs-nutrition-api<br>
# Based on  "Web Scraping and API Fundamentals in Python" Udemy Course: https://www.udemy.com/course/web-scraping-and-api-fundamentals-in-python/

# %%
import requests
import json
import yaml

# %%
# api_id and api_key are stored cread.yml file
with open('cred.yml', 'r') as file:
    cred = yaml.safe_load(file)

# %%
APP_ID = cred["APP_ID"]
APP_KEY = cred["APP_KEY"]

api_endpoint = "https://api.edamam.com/api/nutrition-details"
url = api_endpoint +"?app_id="+APP_ID+"&app_key="+APP_KEY

# %% [markdown]
# ## Sending post request

# %%
headers = {'Content-Type':'application/json'}

# %%
# title and ingredient goes here in string format
receipe = {
        'title':'Nepalese Lentil Curry',
        'ingr':['1 1/2 cups uncooked rice', '1 cup dry Lentils (any color)','1 small yellow onion','3 cloves garlic','1 tablespoon olive oil',
               '16 oz. canned tomatoes','1/3 cup cilantro','1 lime','1 red chili']
}

#submit a post request
r = requests.post(url,headers=headers, json=receipe)

# check the status code
r.status_code
# Out:
# 200

# %% [markdown]
# ### Analyzing the data

# %%
import pandas as pd

# %%
nlc_info = r.json()

# %%
pd.DataFrame(nlc_info['totalNutrients']).T
# Out:
#                                          label  quantity  unit
# ENERC_KCAL                              Energy   2001.49  kcal
# FAT                          Total lipid (fat)   18.8404     g
# FASAT             Fatty acids, total saturated   2.84685     g
# FATRN                 Fatty acids, total trans         0     g
# FAMS        Fatty acids, total monounsaturated   10.9847     g
# FAPU        Fatty acids, total polyunsaturated   3.51977     g
# CHOCDF             Carbohydrate, by difference   390.132     g
# CHOCDF.net                 Carbohydrates (net)   356.891     g
# FIBTG                     Fiber, total dietary   33.2416     g
# SUGAR             Sugars, total including NLEA   22.0859     g
# PROCNT                                 Protein   72.9161     g
# CHOLE                              Cholesterol         0    mg
# NA                                  Sodium, Na    548.52    mg
# CA                                 Calcium, Ca   307.719    mg
# MG                               Magnesium, Mg   262.981    mg
# K                                 Potassium, K    2797.2    mg
# FE                                    Iron, Fe   18.7602    mg
# ZN                                    Zinc, Zn   10.6565    mg
# P                                Phosphorus, P   1000.57    mg
# VITA_RAE                        Vitamin A, RAE   225.741    µg
# VITC            Vitamin C, total ascorbic acid   159.518    mg
# THIA                                   Thiamin   4.59534    mg
# RIBF                                Riboflavin  0.884536    mg
# NIA                                     Niacin    13.797    mg
# VITB6A                             Vitamin B-6   2.42447    mg
# FOLDFE                             Folate, DFE   1014.88    µg
# FOLFD                             Folate, food   1014.88    µg
# FOLAC                               Folic acid         0    µg
# VITB12                            Vitamin B-12         0    µg
# VITD                       Vitamin D (D2 + D3)         0    µg
# TOCPHA            Vitamin E (alpha-tocopherol)   6.17343    mg
# VITK1                Vitamin K (phylloquinone)   53.1887    µg
# WATER                                    Water    654.92     g

# %%
print(json.dumps(nlc_info, indent=4))
# Out:
# {
#     "uri": "http://www.edamam.com/ontologies/edamam.owl#recipe_5f940b7a535246868673d18a26af03e2",
#     "yield": 6.0,
#     "calories": 2001,
#     "totalCO2Emissions": 1721.3112407059998,
#     "co2EmissionsClass": "C",
#     "totalWeight": 1147.9257033333333,
#     "dietLabels": [
#         "HIGH_FIBER",
#         "LOW_FAT",
#         "LOW_SODIUM"
#     ],
#     "healthLabels": [
#         "SUGAR_CONSCIOUS",
#         "VEGAN",
#         "VEGETARIAN",
#         "PESCATARIAN",
#         "MEDITERRANEAN",
#         "DASH",
#         "DAIRY_FREE",
#         "GLUTEN_FREE",
#         "WHEAT_FREE",
#         "EGG_FREE",
#         "MILK_FREE",
#         "PEANUT_FREE",
#         "TREE_NUT_FREE",
#         "SOY_FREE",
#         "FISH_FREE",
#         "SHELLFISH_FREE",
#         "PORK_FREE",
#         "RED_MEAT_FREE",
#         "CRUSTACEAN_FREE",
#         "CELERY_FREE",
#         "MUSTARD_FREE",
#         "SESAME_FREE",
#         "LUPINE_FREE",
#         "MOLLUSK_FREE",
#         "ALCOHOL_FREE",
#         "NO_SUGAR_ADDED",
#         "SULPHITE_FREE",
#         "KOSHER"
#     ],
#     "cautions": [
#         "SULFITES"
#     ],
#     "totalNutrients": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 2001.4914458666665,
#             "unit": "kcal"
#         },
#         "FAT": {
#             "label": "Total lipid (fat)",
#             "quantity": 18.840414258333332,
#             "unit": "g"
#         },
#         "FASAT": {
#             "label": "Fatty acids, total saturated",
#             "quantity": 2.846848072466667,
#             "unit": "g"
#         },
#         "FATRN": {
#             "label": "Fatty acids, total trans",
#             "quantity": 0.0,
#             "unit": "g"
#         },
#         "FAMS": {
#             "label": "Fatty acids, total monounsaturated",
#             "quantity": 10.984708614666667,
#             "unit": "g"
#         },
#         "FAPU": {
#             "label": "Fatty acids, total polyunsaturated",
#             "quantity": 3.5197666270333334,
#             "unit": "g"
#         },
#         "CHOCDF": {
#             "label": "Carbohydrate, by difference",
#             "quantity": 390.13238857233335,
#             "unit": "g"
#         },
#         "CHOCDF.net": {
#             "label": "Carbohydrates (net)",
#             "quantity": 356.890800209,
#             "unit": "g"
#         },
#         "FIBTG": {
#             "label": "Fiber, total dietary",
#             "quantity": 33.24158836333333,
#             "unit": "g"
#         },
#         "SUGAR": {
#             "label": "Sugars, total including NLEA",
#             "quantity": 22.085905435,
#             "unit": "g"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 72.916129723,
#             "unit": "g"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 0.0,
#             "unit": "mg"
#         },
#         "NA": {
#             "label": "Sodium, Na",
#             "quantity": 548.5195588333333,
#             "unit": "mg"
#         },
#         "CA": {
#             "label": "Calcium, Ca",
#             "quantity": 307.71881543333336,
#             "unit": "mg"
#         },
#         "MG": {
#             "label": "Magnesium, Mg",
#             "quantity": 262.9809036666667,
#             "unit": "mg"
#         },
#         "K": {
#             "label": "Potassium, K",
#             "quantity": 2797.203093366667,
#             "unit": "mg"
#         },
#         "FE": {
#             "label": "Iron, Fe",
#             "quantity": 18.760176509,
#             "unit": "mg"
#         },
#         "ZN": {
#             "label": "Zinc, Zn",
#             "quantity": 10.656477510666669,
#             "unit": "mg"
#         },
#         "P": {
#             "label": "Phosphorus, P",
#             "quantity": 1000.5707028999999,
#             "unit": "mg"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A, RAE",
#             "quantity": 225.74147399999998,
#             "unit": "\u00b5g"
#         },
#         "VITC": {
#             "label": "Vitamin C, total ascorbic acid",
#             "quantity": 159.51763862,
#             "unit": "mg"
#         },
#         "THIA": {
#             "label": "Thiamin",
#             "quantity": 4.595339460833333,
#             "unit": "mg"
#         },
#         "RIBF": {
#             "label": "Riboflavin",
#             "quantity": 0.8845358035,
#             "unit": "mg"
#         },
#         "NIA": {
#             "label": "Niacin",
#             "quantity": 13.796977674400003,
#             "unit": "mg"
#         },
#         "VITB6A": {
#             "label": "Vitamin B-6",
#             "quantity": 2.4244691973666668,
#             "unit": "mg"
#         },
#         "FOLDFE": {
#             "label": "Folate, DFE",
#             "quantity": 1014.8790562666666,
#             "unit": "\u00b5g"
#         },
#         "FOLFD": {
#             "label": "Folate, food",
#             "quantity": 1014.8790562666666,
#             "unit": "\u00b5g"
#         },
#         "FOLAC": {
#             "label": "Folic acid",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "VITB12": {
#             "label": "Vitamin B-12",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "VITD": {
#             "label": "Vitamin D (D2 + D3)",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E (alpha-tocopherol)",
#             "quantity": 6.173428316333335,
#             "unit": "mg"
#         },
#         "VITK1": {
#             "label": "Vitamin K (phylloquinone)",
#             "quantity": 53.18873495333333,
#             "unit": "\u00b5g"
#         },
#         "WATER": {
#             "label": "Water",
#             "quantity": 654.9196000933333,
#             "unit": "g"
#         }
#     },
#     "totalDaily": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 100.07457229333333,
#             "unit": "%"
#         },
#         "FAT": {
#             "label": "Fat",
#             "quantity": 28.985252705128204,
#             "unit": "%"
#         },
#         "FASAT": {
#             "label": "Saturated",
#             "quantity": 14.234240362333335,
#             "unit": "%"
#         },
#         "CHOCDF": {
#             "label": "Carbs",
#             "quantity": 130.04412952411113,
#             "unit": "%"
#         },
#         "FIBTG": {
#             "label": "Fiber",
#             "quantity": 132.9663534533333,
#             "unit": "%"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 145.832259446,
#             "unit": "%"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "NA": {
#             "label": "Sodium",
#             "quantity": 22.854981618055557,
#             "unit": "%"
#         },
#         "CA": {
#             "label": "Calcium",
#             "quantity": 30.771881543333336,
#             "unit": "%"
#         },
#         "MG": {
#             "label": "Magnesium",
#             "quantity": 62.61450087301588,
#             "unit": "%"
#         },
#         "K": {
#             "label": "Potassium",
#             "quantity": 59.514959433333345,
#             "unit": "%"
#         },
#         "FE": {
#             "label": "Iron",
#             "quantity": 104.22320282777778,
#             "unit": "%"
#         },
#         "ZN": {
#             "label": "Zinc",
#             "quantity": 96.87706827878789,
#             "unit": "%"
#         },
#         "P": {
#             "label": "Phosphorus",
#             "quantity": 142.93867184285713,
#             "unit": "%"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A",
#             "quantity": 25.082385999999996,
#             "unit": "%"
#         },
#         "VITC": {
#             "label": "Vitamin C",
#             "quantity": 177.2418206888889,
#             "unit": "%"
#         },
#         "THIA": {
#             "label": "Thiamin (B1)",
#             "quantity": 382.94495506944446,
#             "unit": "%"
#         },
#         "RIBF": {
#             "label": "Riboflavin (B2)",
#             "quantity": 68.04121565384617,
#             "unit": "%"
#         },
#         "NIA": {
#             "label": "Niacin (B3)",
#             "quantity": 86.23111046500001,
#             "unit": "%"
#         },
#         "VITB6A": {
#             "label": "Vitamin B6",
#             "quantity": 186.49763056666666,
#             "unit": "%"
#         },
#         "FOLDFE": {
#             "label": "Folate equivalent (total)",
#             "quantity": 253.71976406666664,
#             "unit": "%"
#         },
#         "VITB12": {
#             "label": "Vitamin B12",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "VITD": {
#             "label": "Vitamin D",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E",
#             "quantity": 41.15618877555557,
#             "unit": "%"
#         },
#         "VITK1": {
#             "label": "Vitamin K",
#             "quantity": 44.32394579444444,
#             "unit": "%"
#         }
#     },
#     "ingredients": [
#         {
#             "text": "1 1/2 cups uncooked rice",
#             "parsed": [
#                 {
#                     "quantity": 1.5,
#                     "measure": "cup",
#                     "foodMatch": "rice",
#                     "food": "rice",
#                     "foodId": "food_bpumdjzb5rtqaeabb0kbgbcgr4t9",
#                     "weight": 292.5,
#                     "retainedWeight": 292.5,
#                     "nutrients": {
#                         "RIBF": {
#                             "label": "Riboflavin",
#                             "quantity": 0.1404,
#                             "unit": "mg"
#                         },
#                         "VITD": {
#                             "label": "Vitamin D (D2 + D3), International Units",
#                             "quantity": 0.0,
#                             "unit": "IU"
#                         },
#                         "THIA": {
#                             "label": "Thiamin",
#                             "quantity": 0.20475000000000002,
#                             "unit": "mg"
#                         },
#                         "FAPU": {
#                             "label": "Fatty acids, total polyunsaturated",
#                             "quantity": 0.453375,
#                             "unit": "g"
#                         },
#                         "NIA": {
#                             "label": "Niacin",
#                             "quantity": 4.68,
#                             "unit": "mg"
#                         },
#                         "ENERC_KCAL": {
#                             "label": "Energy",
#                             "quantity": 1053.0,
#                             "unit": "kcal"
#                         },
#                         "FASAT": {
#                             "label": "Fatty acids, total saturated",
#                             "quantity": 0.46215000000000006,
#                             "unit": "g"
#                         },
#                         "VITC": {
#                             "label": "Vitamin C, total ascorbic acid",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "PROCNT": {
#                             "label": "Protein",
#                             "quantity": 19.33425,
#                             "unit": "g"
#                         },
#                         "CHOLE": {
#                             "label": "Cholesterol",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "FAMS": {
#                             "label": "Fatty acids, total monounsaturated",
#                             "quantity": 0.5294249999999999,
#                             "unit": "g"
#                         },
#                         "CHOCDF": {
#                             "label": "Carbohydrate, by difference",
#                             "quantity": 231.9525,
#                             "unit": "g"
#                         },
#                         "FAT": {
#                             "label": "Total lipid (fat)",
#                             "quantity": 1.6964999999999997,
#                             "unit": "g"
#                         },
#                         "VITB6A": {
#                             "label": "Vitamin B-6",
#                             "quantity": 0.4241249999999999,
#                             "unit": "mg"
#                         },
#                         "VITB12": {
#                             "label": "Vitamin B-12",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "WATER": {
#                             "label": "Water",
#                             "quantity": 37.7325,
#                             "unit": "g"
#                         },
#                         "K": {
#                             "label": "Potassium, K",
#                             "quantity": 251.55,
#                             "unit": "mg"
#                         },
#                         "P": {
#                             "label": "Phosphorus, P",
#                             "quantity": 315.9,
#                             "unit": "mg"
#                         },
#                         "NA": {
#                             "label": "Sodium, Na",
#                             "quantity": 2.925,
#                             "unit": "mg"
#                         },
#                         "ZN": {
#                             "label": "Zinc, Zn",
#                             "quantity": 3.3929999999999993,
#                             "unit": "mg"
#                         },
#                         "CA": {
#                             "label": "Calcium, Ca",
#                             "quantity": 26.325,
#                             "unit": "mg"
#                         },
#                         "MG": {
#                             "label": "Magnesium, Mg",
#                             "quantity": 102.375,
#                             "unit": "mg"
#                         },
#                         "FE": {
#                             "label": "Iron, Fe",
#                             "quantity": 2.34,
#                             "unit": "mg"
#                         },
#                         "FOLFD": {
#                             "label": "Folate, food",
#                             "quantity": 26.325,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLAC": {
#                             "label": "Folic acid",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLDFE": {
#                             "label": "Folate, DFE",
#                             "quantity": 26.325,
#                             "unit": "\u00b5g"
#                         }
#                     },
#                     "measureURI": "http://www.edamam.com/ontologies/edamam.owl#Measure_cup",
#                     "status": "OK"
#                 }
#             ]
#         },
#         {
#             "text": "1 cup dry Lentils (any color)",
#             "parsed": [
#                 {
#                     "quantity": 1.0,
#                     "measure": "cup",
#                     "foodMatch": "Lentils",
#                     "food": "lentils",
#                     "foodId": "food_bg13k5uafva4jta78xnjcaqkli85",
#                     "weight": 192.0,
#                     "retainedWeight": 192.0,
#                     "nutrients": {
#                         "VITD": {
#                             "label": "Vitamin D (D2 + D3), International Units",
#                             "quantity": 0.0,
#                             "unit": "IU"
#                         },
#                         "FATRN": {
#                             "label": "Fatty acids, total trans",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "ENERC_KCAL": {
#                             "label": "Energy",
#                             "quantity": 675.84,
#                             "unit": "kcal"
#                         },
#                         "FASAT": {
#                             "label": "Fatty acids, total saturated",
#                             "quantity": 0.29568,
#                             "unit": "g"
#                         },
#                         "VITA_RAE": {
#                             "label": "Vitamin A, RAE",
#                             "quantity": 3.84,
#                             "unit": "\u00b5g"
#                         },
#                         "PROCNT": {
#                             "label": "Protein",
#                             "quantity": 47.232000000000006,
#                             "unit": "g"
#                         },
#                         "TOCPHA": {
#                             "label": "Vitamin E (alpha-tocopherol)",
#                             "quantity": 0.9408,
#                             "unit": "mg"
#                         },
#                         "CHOLE": {
#                             "label": "Cholesterol",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "CHOCDF": {
#                             "label": "Carbohydrate, by difference",
#                             "quantity": 121.728,
#                             "unit": "g"
#                         },
#                         "FAT": {
#                             "label": "Total lipid (fat)",
#                             "quantity": 2.0352,
#                             "unit": "g"
#                         },
#                         "FIBTG": {
#                             "label": "Fiber, total dietary",
#                             "quantity": 20.543999999999997,
#                             "unit": "g"
#                         },
#                         "RIBF": {
#                             "label": "Riboflavin",
#                             "quantity": 0.40512,
#                             "unit": "mg"
#                         },
#                         "THIA": {
#                             "label": "Thiamin",
#                             "quantity": 1.6761599999999999,
#                             "unit": "mg"
#                         },
#                         "FAPU": {
#                             "label": "Fatty acids, total polyunsaturated",
#                             "quantity": 1.0099200000000002,
#                             "unit": "g"
#                         },
#                         "NIA": {
#                             "label": "Niacin",
#                             "quantity": 4.992000000000001,
#                             "unit": "mg"
#                         },
#                         "VITC": {
#                             "label": "Vitamin C, total ascorbic acid",
#                             "quantity": 8.64,
#                             "unit": "mg"
#                         },
#                         "FAMS": {
#                             "label": "Fatty acids, total monounsaturated",
#                             "quantity": 0.37056,
#                             "unit": "g"
#                         },
#                         "VITB6A": {
#                             "label": "Vitamin B-6",
#                             "quantity": 1.0368000000000002,
#                             "unit": "mg"
#                         },
#                         "VITB12": {
#                             "label": "Vitamin B-12",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "WATER": {
#                             "label": "Water",
#                             "quantity": 15.859200000000001,
#                             "unit": "g"
#                         },
#                         "K": {
#                             "label": "Potassium, K",
#                             "quantity": 1299.84,
#                             "unit": "mg"
#                         },
#                         "P": {
#                             "label": "Phosphorus, P",
#                             "quantity": 539.52,
#                             "unit": "mg"
#                         },
#                         "NA": {
#                             "label": "Sodium, Na",
#                             "quantity": 11.52,
#                             "unit": "mg"
#                         },
#                         "ZN": {
#                             "label": "Zinc, Zn",
#                             "quantity": 6.2784,
#                             "unit": "mg"
#                         },
#                         "SUGAR": {
#                             "label": "Sugars, total including NLEA",
#                             "quantity": 3.8975999999999997,
#                             "unit": "g"
#                         },
#                         "CA": {
#                             "label": "Calcium, Ca",
#                             "quantity": 67.2,
#                             "unit": "mg"
#                         },
#                         "MG": {
#                             "label": "Magnesium, Mg",
#                             "quantity": 90.24,
#                             "unit": "mg"
#                         },
#                         "FE": {
#                             "label": "Iron, Fe",
#                             "quantity": 12.4992,
#                             "unit": "mg"
#                         },
#                         "VITK1": {
#                             "label": "Vitamin K (phylloquinone)",
#                             "quantity": 9.6,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLFD": {
#                             "label": "Folate, food",
#                             "quantity": 919.68,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLAC": {
#                             "label": "Folic acid",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLDFE": {
#                             "label": "Folate, DFE",
#                             "quantity": 919.68,
#                             "unit": "\u00b5g"
#                         }
#                     },
#                     "measureURI": "http://www.edamam.com/ontologies/edamam.owl#Measure_cup",
#                     "status": "OK"
#                 }
#             ]
#         },
#         {
#             "text": "1 small yellow onion",
#             "parsed": [
#                 {
#                     "quantity": 1.0,
#                     "measure": "whole",
#                     "foodMatch": "yellow onion",
#                     "food": "onions",
#                     "foodId": "food_bmrvi4ob4binw9a5m7l07amlfcoy",
#                     "weight": 70.0,
#                     "retainedWeight": 70.0,
#                     "nutrients": {
#                         "VITD": {
#                             "label": "Vitamin D (D2 + D3), International Units",
#                             "quantity": 0.0,
#                             "unit": "IU"
#                         },
#                         "FATRN": {
#                             "label": "Fatty acids, total trans",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "ENERC_KCAL": {
#                             "label": "Energy",
#                             "quantity": 28.0,
#                             "unit": "kcal"
#                         },
#                         "FASAT": {
#                             "label": "Fatty acids, total saturated",
#                             "quantity": 0.029400000000000003,
#                             "unit": "g"
#                         },
#                         "VITA_RAE": {
#                             "label": "Vitamin A, RAE",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "PROCNT": {
#                             "label": "Protein",
#                             "quantity": 0.77,
#                             "unit": "g"
#                         },
#                         "TOCPHA": {
#                             "label": "Vitamin E (alpha-tocopherol)",
#                             "quantity": 0.014000000000000002,
#                             "unit": "mg"
#                         },
#                         "CHOLE": {
#                             "label": "Cholesterol",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "CHOCDF": {
#                             "label": "Carbohydrate, by difference",
#                             "quantity": 6.537999999999999,
#                             "unit": "g"
#                         },
#                         "FAT": {
#                             "label": "Total lipid (fat)",
#                             "quantity": 0.07,
#                             "unit": "g"
#                         },
#                         "FIBTG": {
#                             "label": "Fiber, total dietary",
#                             "quantity": 1.19,
#                             "unit": "g"
#                         },
#                         "RIBF": {
#                             "label": "Riboflavin",
#                             "quantity": 0.0189,
#                             "unit": "mg"
#                         },
#                         "THIA": {
#                             "label": "Thiamin",
#                             "quantity": 0.0322,
#                             "unit": "mg"
#                         },
#                         "FAPU": {
#                             "label": "Fatty acids, total polyunsaturated",
#                             "quantity": 0.0119,
#                             "unit": "g"
#                         },
#                         "NIA": {
#                             "label": "Niacin",
#                             "quantity": 0.08120000000000001,
#                             "unit": "mg"
#                         },
#                         "VITC": {
#                             "label": "Vitamin C, total ascorbic acid",
#                             "quantity": 5.18,
#                             "unit": "mg"
#                         },
#                         "FAMS": {
#                             "label": "Fatty acids, total monounsaturated",
#                             "quantity": 0.009099999999999999,
#                             "unit": "g"
#                         },
#                         "VITB6A": {
#                             "label": "Vitamin B-6",
#                             "quantity": 0.084,
#                             "unit": "mg"
#                         },
#                         "VITB12": {
#                             "label": "Vitamin B-12",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "WATER": {
#                             "label": "Water",
#                             "quantity": 62.37,
#                             "unit": "g"
#                         },
#                         "K": {
#                             "label": "Potassium, K",
#                             "quantity": 102.2,
#                             "unit": "mg"
#                         },
#                         "P": {
#                             "label": "Phosphorus, P",
#                             "quantity": 20.3,
#                             "unit": "mg"
#                         },
#                         "NA": {
#                             "label": "Sodium, Na",
#                             "quantity": 2.8,
#                             "unit": "mg"
#                         },
#                         "ZN": {
#                             "label": "Zinc, Zn",
#                             "quantity": 0.11900000000000001,
#                             "unit": "mg"
#                         },
#                         "SUGAR": {
#                             "label": "Sugars, total including NLEA",
#                             "quantity": 2.968,
#                             "unit": "g"
#                         },
#                         "CA": {
#                             "label": "Calcium, Ca",
#                             "quantity": 16.1,
#                             "unit": "mg"
#                         },
#                         "MG": {
#                             "label": "Magnesium, Mg",
#                             "quantity": 7.0,
#                             "unit": "mg"
#                         },
#                         "FE": {
#                             "label": "Iron, Fe",
#                             "quantity": 0.147,
#                             "unit": "mg"
#                         },
#                         "VITK1": {
#                             "label": "Vitamin K (phylloquinone)",
#                             "quantity": 0.28,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLFD": {
#                             "label": "Folate, food",
#                             "quantity": 13.3,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLAC": {
#                             "label": "Folic acid",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLDFE": {
#                             "label": "Folate, DFE",
#                             "quantity": 13.3,
#                             "unit": "\u00b5g"
#                         }
#                     },
#                     "measureURI": "http://www.edamam.com/ontologies/edamam.owl#Measure_unit",
#                     "status": "OK"
#                 }
#             ]
#         },
#         {
#             "text": "3 cloves garlic",
#             "parsed": [
#                 {
#                     "quantity": 3.0,
#                     "measure": "clove",
#                     "foodMatch": "garlic",
#                     "food": "garlic",
#                     "foodId": "food_avtcmx6bgjv1jvay6s6stan8dnyp",
#                     "weight": 9.0,
#                     "retainedWeight": 9.0,
#                     "nutrients": {
#                         "RIBF": {
#                             "label": "Riboflavin",
#                             "quantity": 0.009899999999999999,
#                             "unit": "mg"
#                         },
#                         "VITD": {
#                             "label": "Vitamin D (D2 + D3), International Units",
#                             "quantity": 0.0,
#                             "unit": "IU"
#                         },
#                         "THIA": {
#                             "label": "Thiamin",
#                             "quantity": 0.018000000000000002,
#                             "unit": "mg"
#                         },
#                         "FAPU": {
#                             "label": "Fatty acids, total polyunsaturated",
#                             "quantity": 0.02241,
#                             "unit": "g"
#                         },
#                         "FATRN": {
#                             "label": "Fatty acids, total trans",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "NIA": {
#                             "label": "Niacin",
#                             "quantity": 0.063,
#                             "unit": "mg"
#                         },
#                         "ENERC_KCAL": {
#                             "label": "Energy",
#                             "quantity": 13.41,
#                             "unit": "kcal"
#                         },
#                         "FASAT": {
#                             "label": "Fatty acids, total saturated",
#                             "quantity": 0.00801,
#                             "unit": "g"
#                         },
#                         "VITA_RAE": {
#                             "label": "Vitamin A, RAE",
#                             "quantity": 0.24299999999999997,
#                             "unit": "\u00b5g"
#                         },
#                         "VITC": {
#                             "label": "Vitamin C, total ascorbic acid",
#                             "quantity": 2.8080000000000003,
#                             "unit": "mg"
#                         },
#                         "PROCNT": {
#                             "label": "Protein",
#                             "quantity": 0.5724,
#                             "unit": "g"
#                         },
#                         "TOCPHA": {
#                             "label": "Vitamin E (alpha-tocopherol)",
#                             "quantity": 0.0072,
#                             "unit": "mg"
#                         },
#                         "CHOLE": {
#                             "label": "Cholesterol",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "FAMS": {
#                             "label": "Fatty acids, total monounsaturated",
#                             "quantity": 0.00099,
#                             "unit": "g"
#                         },
#                         "CHOCDF": {
#                             "label": "Carbohydrate, by difference",
#                             "quantity": 2.9790000000000005,
#                             "unit": "g"
#                         },
#                         "FAT": {
#                             "label": "Total lipid (fat)",
#                             "quantity": 0.045,
#                             "unit": "g"
#                         },
#                         "VITB6A": {
#                             "label": "Vitamin B-6",
#                             "quantity": 0.1116,
#                             "unit": "mg"
#                         },
#                         "VITB12": {
#                             "label": "Vitamin B-12",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FIBTG": {
#                             "label": "Fiber, total dietary",
#                             "quantity": 0.18900000000000003,
#                             "unit": "g"
#                         },
#                         "WATER": {
#                             "label": "Water",
#                             "quantity": 5.274,
#                             "unit": "g"
#                         },
#                         "K": {
#                             "label": "Potassium, K",
#                             "quantity": 36.09,
#                             "unit": "mg"
#                         },
#                         "P": {
#                             "label": "Phosphorus, P",
#                             "quantity": 13.77,
#                             "unit": "mg"
#                         },
#                         "NA": {
#                             "label": "Sodium, Na",
#                             "quantity": 1.53,
#                             "unit": "mg"
#                         },
#                         "ZN": {
#                             "label": "Zinc, Zn",
#                             "quantity": 0.10439999999999999,
#                             "unit": "mg"
#                         },
#                         "SUGAR": {
#                             "label": "Sugars, total including NLEA",
#                             "quantity": 0.09,
#                             "unit": "g"
#                         },
#                         "CA": {
#                             "label": "Calcium, Ca",
#                             "quantity": 16.29,
#                             "unit": "mg"
#                         },
#                         "MG": {
#                             "label": "Magnesium, Mg",
#                             "quantity": 2.25,
#                             "unit": "mg"
#                         },
#                         "FE": {
#                             "label": "Iron, Fe",
#                             "quantity": 0.153,
#                             "unit": "mg"
#                         },
#                         "VITK1": {
#                             "label": "Vitamin K (phylloquinone)",
#                             "quantity": 0.153,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLFD": {
#                             "label": "Folate, food",
#                             "quantity": 0.27,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLAC": {
#                             "label": "Folic acid",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLDFE": {
#                             "label": "Folate, DFE",
#                             "quantity": 0.27,
#                             "unit": "\u00b5g"
#                         }
#                     },
#                     "measureURI": "http://www.edamam.com/ontologies/edamam.owl#Measure_clove",
#                     "status": "OK"
#                 }
#             ]
#         },
#         {
#             "text": "1 tablespoon olive oil",
#             "parsed": [
#                 {
#                     "quantity": 1.0,
#                     "measure": "tablespoon",
#                     "foodMatch": "olive oil",
#                     "food": "olive oil",
#                     "foodId": "food_b1d1icuad3iktrbqby0hiagafaz7",
#                     "weight": 13.5,
#                     "retainedWeight": 13.5,
#                     "nutrients": {
#                         "VITD": {
#                             "label": "Vitamin D (D2 + D3), International Units",
#                             "quantity": 0.0,
#                             "unit": "IU"
#                         },
#                         "ENERC_KCAL": {
#                             "label": "Energy",
#                             "quantity": 119.34,
#                             "unit": "kcal"
#                         },
#                         "FASAT": {
#                             "label": "Fatty acids, total saturated",
#                             "quantity": 1.8630000000000002,
#                             "unit": "g"
#                         },
#                         "VITA_RAE": {
#                             "label": "Vitamin A, RAE",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "PROCNT": {
#                             "label": "Protein",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "TOCPHA": {
#                             "label": "Vitamin E (alpha-tocopherol)",
#                             "quantity": 1.944,
#                             "unit": "mg"
#                         },
#                         "CHOLE": {
#                             "label": "Cholesterol",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "CHOCDF": {
#                             "label": "Carbohydrate, by difference",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "FAT": {
#                             "label": "Total lipid (fat)",
#                             "quantity": 13.5,
#                             "unit": "g"
#                         },
#                         "FIBTG": {
#                             "label": "Fiber, total dietary",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "RIBF": {
#                             "label": "Riboflavin",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "THIA": {
#                             "label": "Thiamin",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "FAPU": {
#                             "label": "Fatty acids, total polyunsaturated",
#                             "quantity": 1.4175,
#                             "unit": "g"
#                         },
#                         "NIA": {
#                             "label": "Niacin",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "VITC": {
#                             "label": "Vitamin C, total ascorbic acid",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "FAMS": {
#                             "label": "Fatty acids, total monounsaturated",
#                             "quantity": 9.855,
#                             "unit": "g"
#                         },
#                         "VITB6A": {
#                             "label": "Vitamin B-6",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "VITB12": {
#                             "label": "Vitamin B-12",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "WATER": {
#                             "label": "Water",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "K": {
#                             "label": "Potassium, K",
#                             "quantity": 0.135,
#                             "unit": "mg"
#                         },
#                         "P": {
#                             "label": "Phosphorus, P",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "NA": {
#                             "label": "Sodium, Na",
#                             "quantity": 0.27,
#                             "unit": "mg"
#                         },
#                         "ZN": {
#                             "label": "Zinc, Zn",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "SUGAR": {
#                             "label": "Sugars, total including NLEA",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "CA": {
#                             "label": "Calcium, Ca",
#                             "quantity": 0.135,
#                             "unit": "mg"
#                         },
#                         "MG": {
#                             "label": "Magnesium, Mg",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "FE": {
#                             "label": "Iron, Fe",
#                             "quantity": 0.0756,
#                             "unit": "mg"
#                         },
#                         "VITK1": {
#                             "label": "Vitamin K (phylloquinone)",
#                             "quantity": 8.127,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLFD": {
#                             "label": "Folate, food",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLAC": {
#                             "label": "Folic acid",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLDFE": {
#                             "label": "Folate, DFE",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         }
#                     },
#                     "measureURI": "http://www.edamam.com/ontologies/edamam.owl#Measure_tablespoon",
#                     "status": "OK"
#                 }
#             ]
#         },
#         {
#             "text": "16 oz. canned tomatoes",
#             "parsed": [
#                 {
#                     "quantity": 16.0,
#                     "measure": "ounce",
#                     "foodMatch": "canned tomatoes",
#                     "food": "canned ripe red tomatoes",
#                     "foodId": "food_bnmkkwqa9h2p87bz171eoby0bsey",
#                     "weight": 453.59237,
#                     "retainedWeight": 453.59237,
#                     "nutrients": {
#                         "VITD": {
#                             "label": "Vitamin D (D2 + D3), International Units",
#                             "quantity": 0.0,
#                             "unit": "IU"
#                         },
#                         "FATRN": {
#                             "label": "Fatty acids, total trans",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "ENERC_KCAL": {
#                             "label": "Energy",
#                             "quantity": 72.57477920000001,
#                             "unit": "kcal"
#                         },
#                         "FASAT": {
#                             "label": "Fatty acids, total saturated",
#                             "quantity": 0.15422140580000002,
#                             "unit": "g"
#                         },
#                         "VITA_RAE": {
#                             "label": "Vitamin A, RAE",
#                             "quantity": 90.718474,
#                             "unit": "\u00b5g"
#                         },
#                         "PROCNT": {
#                             "label": "Protein",
#                             "quantity": 3.5833797230000006,
#                             "unit": "g"
#                         },
#                         "TOCPHA": {
#                             "label": "Vitamin E (alpha-tocopherol)",
#                             "quantity": 2.676194983,
#                             "unit": "mg"
#                         },
#                         "CHOLE": {
#                             "label": "Cholesterol",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "CHOCDF": {
#                             "label": "Carbohydrate, by difference",
#                             "quantity": 15.739655239000001,
#                             "unit": "g"
#                         },
#                         "FAT": {
#                             "label": "Total lipid (fat)",
#                             "quantity": 1.1339809250000001,
#                             "unit": "g"
#                         },
#                         "FIBTG": {
#                             "label": "Fiber, total dietary",
#                             "quantity": 8.61825503,
#                             "unit": "g"
#                         },
#                         "RIBF": {
#                             "label": "Riboflavin",
#                             "quantity": 0.24947580350000004,
#                             "unit": "mg"
#                         },
#                         "THIA": {
#                             "label": "Thiamin",
#                             "quantity": 2.6081561275,
#                             "unit": "mg"
#                         },
#                         "FAPU": {
#                             "label": "Fatty acids, total polyunsaturated",
#                             "quantity": 0.4581282937,
#                             "unit": "g"
#                         },
#                         "NIA": {
#                             "label": "Niacin",
#                             "quantity": 3.2295776743999998,
#                             "unit": "mg"
#                         },
#                         "VITC": {
#                             "label": "Vitamin C, total ascorbic acid",
#                             "quantity": 57.15263862,
# ...
#                         "FOLAC": {
#                             "label": "Folic acid",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLDFE": {
#                             "label": "Folate, DFE",
#                             "quantity": 3.306666666666666,
#                             "unit": "\u00b5g"
#                         }
#                     },
#                     "measureURI": "http://www.edamam.com/ontologies/edamam.owl#Measure_cup",
#                     "status": "OK"
#                 }
#             ]
#         },
#         {
#             "text": "1 lime",
#             "parsed": [
#                 {
#                     "quantity": 1.0,
#                     "measure": "whole",
#                     "foodMatch": "lime",
#                     "food": "limes",
#                     "foodId": "food_av58muyb8kg92fbk0g8g8aui5knv",
#                     "weight": 67.0,
#                     "retainedWeight": 67.0,
#                     "nutrients": {
#                         "RIBF": {
#                             "label": "Riboflavin",
#                             "quantity": 0.0134,
#                             "unit": "mg"
#                         },
#                         "VITD": {
#                             "label": "Vitamin D (D2 + D3), International Units",
#                             "quantity": 0.0,
#                             "unit": "IU"
#                         },
#                         "THIA": {
#                             "label": "Thiamin",
#                             "quantity": 0.020099999999999996,
#                             "unit": "mg"
#                         },
#                         "FAPU": {
#                             "label": "Fatty acids, total polyunsaturated",
#                             "quantity": 0.03685,
#                             "unit": "g"
#                         },
#                         "FATRN": {
#                             "label": "Fatty acids, total trans",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "NIA": {
#                             "label": "Niacin",
#                             "quantity": 0.134,
#                             "unit": "mg"
#                         },
#                         "ENERC_KCAL": {
#                             "label": "Energy",
#                             "quantity": 20.1,
#                             "unit": "kcal"
#                         },
#                         "FASAT": {
#                             "label": "Fatty acids, total saturated",
#                             "quantity": 0.01474,
#                             "unit": "g"
#                         },
#                         "VITA_RAE": {
#                             "label": "Vitamin A, RAE",
#                             "quantity": 1.34,
#                             "unit": "\u00b5g"
#                         },
#                         "VITC": {
#                             "label": "Vitamin C, total ascorbic acid",
#                             "quantity": 19.497,
#                             "unit": "mg"
#                         },
#                         "PROCNT": {
#                             "label": "Protein",
#                             "quantity": 0.469,
#                             "unit": "g"
#                         },
#                         "TOCPHA": {
#                             "label": "Vitamin E (alpha-tocopherol)",
#                             "quantity": 0.1474,
#                             "unit": "mg"
#                         },
#                         "CHOLE": {
#                             "label": "Cholesterol",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "FAMS": {
#                             "label": "Fatty acids, total monounsaturated",
#                             "quantity": 0.012729999999999998,
#                             "unit": "g"
#                         },
#                         "CHOCDF": {
#                             "label": "Carbohydrate, by difference",
#                             "quantity": 7.035,
#                             "unit": "g"
#                         },
#                         "FAT": {
#                             "label": "Total lipid (fat)",
#                             "quantity": 0.134,
#                             "unit": "g"
#                         },
#                         "VITB6A": {
#                             "label": "Vitamin B-6",
#                             "quantity": 0.02881,
#                             "unit": "mg"
#                         },
#                         "VITB12": {
#                             "label": "Vitamin B-12",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FIBTG": {
#                             "label": "Fiber, total dietary",
#                             "quantity": 1.876,
#                             "unit": "g"
#                         },
#                         "WATER": {
#                             "label": "Water",
#                             "quantity": 59.160999999999994,
#                             "unit": "g"
#                         },
#                         "K": {
#                             "label": "Potassium, K",
#                             "quantity": 68.34,
#                             "unit": "mg"
#                         },
#                         "P": {
#                             "label": "Phosphorus, P",
#                             "quantity": 12.06,
#                             "unit": "mg"
#                         },
#                         "NA": {
#                             "label": "Sodium, Na",
#                             "quantity": 1.34,
#                             "unit": "mg"
#                         },
#                         "ZN": {
#                             "label": "Zinc, Zn",
#                             "quantity": 0.0737,
#                             "unit": "mg"
#                         },
#                         "SUGAR": {
#                             "label": "Sugars, total including NLEA",
#                             "quantity": 1.1322999999999999,
#                             "unit": "g"
#                         },
#                         "CA": {
#                             "label": "Calcium, Ca",
#                             "quantity": 22.11,
#                             "unit": "mg"
#                         },
#                         "MG": {
#                             "label": "Magnesium, Mg",
#                             "quantity": 4.02,
#                             "unit": "mg"
#                         },
#                         "FE": {
#                             "label": "Iron, Fe",
#                             "quantity": 0.40199999999999997,
#                             "unit": "mg"
#                         },
#                         "VITK1": {
#                             "label": "Vitamin K (phylloquinone)",
#                             "quantity": 0.40199999999999997,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLFD": {
#                             "label": "Folate, food",
#                             "quantity": 5.36,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLAC": {
#                             "label": "Folic acid",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLDFE": {
#                             "label": "Folate, DFE",
#                             "quantity": 5.36,
#                             "unit": "\u00b5g"
#                         }
#                     },
#                     "measureURI": "http://www.edamam.com/ontologies/edamam.owl#Measure_unit",
#                     "status": "OK"
#                 }
#             ]
#         },
#         {
#             "text": "1 red chili",
#             "parsed": [
#                 {
#                     "quantity": 1.0,
#                     "measure": "whole",
#                     "foodMatch": "red chili",
#                     "food": "red chili",
#                     "foodId": "food_a6g98mqatzj7vca6ms3bnbzqxf3s",
#                     "weight": 45.0,
#                     "retainedWeight": 45.0,
#                     "nutrients": {
#                         "RIBF": {
#                             "label": "Riboflavin",
#                             "quantity": 0.0387,
#                             "unit": "mg"
#                         },
#                         "VITD": {
#                             "label": "Vitamin D (D2 + D3), International Units",
#                             "quantity": 0.0,
#                             "unit": "IU"
#                         },
#                         "THIA": {
#                             "label": "Thiamin",
#                             "quantity": 0.0324,
#                             "unit": "mg"
#                         },
#                         "FAPU": {
#                             "label": "Fatty acids, total polyunsaturated",
#                             "quantity": 0.10754999999999999,
#                             "unit": "g"
#                         },
#                         "FATRN": {
#                             "label": "Fatty acids, total trans",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "NIA": {
#                             "label": "Niacin",
#                             "quantity": 0.5579999999999999,
#                             "unit": "mg"
#                         },
#                         "ENERC_KCAL": {
#                             "label": "Energy",
#                             "quantity": 18.0,
#                             "unit": "kcal"
#                         },
#                         "FASAT": {
#                             "label": "Fatty acids, total saturated",
#                             "quantity": 0.0189,
#                             "unit": "g"
#                         },
#                         "VITA_RAE": {
#                             "label": "Vitamin A, RAE",
#                             "quantity": 21.6,
#                             "unit": "\u00b5g"
#                         },
#                         "VITC": {
#                             "label": "Vitamin C, total ascorbic acid",
#                             "quantity": 64.8,
#                             "unit": "mg"
#                         },
#                         "PROCNT": {
#                             "label": "Protein",
#                             "quantity": 0.8415,
#                             "unit": "g"
#                         },
#                         "TOCPHA": {
#                             "label": "Vitamin E (alpha-tocopherol)",
#                             "quantity": 0.3105,
#                             "unit": "mg"
#                         },
#                         "CHOLE": {
#                             "label": "Cholesterol",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "FAMS": {
#                             "label": "Fatty acids, total monounsaturated",
#                             "quantity": 0.0108,
#                             "unit": "g"
#                         },
#                         "CHOCDF": {
#                             "label": "Carbohydrate, by difference",
#                             "quantity": 3.9645000000000006,
#                             "unit": "g"
#                         },
#                         "FAT": {
#                             "label": "Total lipid (fat)",
#                             "quantity": 0.198,
#                             "unit": "g"
#                         },
#                         "VITB6A": {
#                             "label": "Vitamin B-6",
#                             "quantity": 0.22769999999999999,
#                             "unit": "mg"
#                         },
#                         "VITB12": {
#                             "label": "Vitamin B-12",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FIBTG": {
#                             "label": "Fiber, total dietary",
#                             "quantity": 0.675,
#                             "unit": "g"
#                         },
#                         "WATER": {
#                             "label": "Water",
#                             "quantity": 39.6,
#                             "unit": "g"
#                         },
#                         "K": {
#                             "label": "Potassium, K",
#                             "quantity": 144.9,
#                             "unit": "mg"
#                         },
#                         "P": {
#                             "label": "Phosphorus, P",
#                             "quantity": 19.35,
#                             "unit": "mg"
#                         },
#                         "NA": {
#                             "label": "Sodium, Na",
#                             "quantity": 4.05,
#                             "unit": "mg"
#                         },
#                         "ZN": {
#                             "label": "Zinc, Zn",
#                             "quantity": 0.117,
#                             "unit": "mg"
#                         },
#                         "SUGAR": {
#                             "label": "Sugars, total including NLEA",
#                             "quantity": 2.385,
#                             "unit": "g"
#                         },
#                         "CA": {
#                             "label": "Calcium, Ca",
#                             "quantity": 6.3,
#                             "unit": "mg"
#                         },
#                         "MG": {
#                             "label": "Magnesium, Mg",
#                             "quantity": 10.35,
#                             "unit": "mg"
#                         },
#                         "FE": {
#                             "label": "Iron, Fe",
#                             "quantity": 0.4635,
#                             "unit": "mg"
#                         },
#                         "VITK1": {
#                             "label": "Vitamin K (phylloquinone)",
#                             "quantity": 6.3,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLFD": {
#                             "label": "Folate, food",
#                             "quantity": 10.35,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLAC": {
#                             "label": "Folic acid",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLDFE": {
#                             "label": "Folate, DFE",
#                             "quantity": 10.35,
#                             "unit": "\u00b5g"
#                         }
#                     },
#                     "measureURI": "http://www.edamam.com/ontologies/edamam.owl#Measure_unit",
#                     "status": "OK"
#                 }
#             ]
#         }
#     ],
#     "cuisineType": [
#         "indian"
#     ],
#     "mealType": [
#         "lunch/dinner"
#     ],
#     "dishType": [
#         "main course"
#     ],
#     "totalNutrientsKCal": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 2002,
#             "unit": "kcal"
#         },
#         "PROCNT_KCAL": {
#             "label": "Calories from protein",
#             "quantity": 289,
#             "unit": "kcal"
#         },
#         "FAT_KCAL": {
#             "label": "Calories from fat",
#             "quantity": 168,
#             "unit": "kcal"
#         },
#         "CHOCDF_KCAL": {
#             "label": "Calories from carbohydrates",
#             "quantity": 1545,
#             "unit": "kcal"
#         }
#     }
# }
